# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import ttest_ind
from scipy import stats
# %matplotlib inline

# Read CSV into DataFrame
df = pd.read_csv("correct_output.csv")
df
# Out:
#                             School Name  School ID School Type  School Size  \
# 0       University of California-Merced     445188      Public       7375.0
# 1     University of Southern California     123961     Private      18942.0
# 2              West Los Angeles College     125471      Public       9622.0
# 3              Pueblo Community College     127884      Public       3641.0
# 4        University of Colorado Boulder     126614      Public      28565.0
# ...                                 ...        ...         ...          ...
# 1001          Fresno Pacific University     114813     Private       2791.0
# 1002                   Foothill College     114716      Public      13873.0
# 1003                    Skyline College     123509      Public       8084.0
# 1004      Eastern Florida State College     132693      Public      12306.0
# 1005                    Broward College     132709      Public      35127.0
#
#       10 Year Median Earnings  10 Year Mean Earnings        Lat         Lng  \
# 0                         NaN                    NaN  37.366237 -120.424944
# 1                     74000.0                88800.0  34.021281 -118.284169
# 2                     31500.0                37300.0  34.004512 -118.386664
# 3                     27700.0                31900.0  38.262124 -104.636258
# 4                     50800.0                59700.0  40.008781 -105.270823
# ...                       ...                    ...        ...         ...
# 1001                  43900.0                45600.0  36.726831 -119.735199
# 1002                  46500.0                58300.0  37.361655 -122.127964
# 1003                  40500.0                45600.0  37.630420 -122.467335
# 1004                  29300.0                34000.0  28.383610  -80.756474
# 1005                  34900.0                38700.0  26.119422  -80.141830
#
#                  City State  SAT Scores  ACT Scores  Admission Rate  \
# 0              Merced    CA      1114.0        24.0          0.6979
# 1         Los Angeles    CA      1437.0        32.0          0.1595
# 2         Culver City    CA         NaN         NaN             NaN
# 3              Pueblo    CO         NaN         NaN             NaN
# 4             Boulder    CO      1293.0        28.0          0.7984
# ...               ...   ...         ...         ...             ...
# 1001           Fresno    CA      1050.0        20.0          0.7239
# 1002  Los Altos Hills    CA         NaN         NaN             NaN
# 1003        San Bruno    CA         NaN         NaN             NaN
# 1004            Cocoa    FL         NaN         NaN             NaN
# 1005  Fort Lauderdale    FL         NaN         NaN             NaN
#
#       Average Gross Cost  Average Net Price  Locale
# 0                34330.0            13223.0    41.0
# 1                69547.0            30232.0    11.0
# 2                13255.0             6823.0    21.0
# 3                20783.0            14860.0    12.0
# 4                29215.0            20706.0    12.0
# ...                  ...                ...     ...
# 1001             38420.0            16177.0    11.0
# 1002             11726.0             5291.0    21.0
# 1003              8929.0             1945.0    21.0
# 1004             10069.0             5974.0    21.0
# 1005             13717.0             9505.0    12.0
#
# [1006 rows x 16 columns]

# %%
# Clean data
df_clean = df[["School Name", "School Type", "10 Year Median Earnings", "10 Year Mean Earnings", "SAT Scores", "ACT Scores"]]
df_clean = df_clean.dropna()
new_df = df_clean
new_df
# Out:
#                                School Name School Type  \
# 1        University of Southern California     Private
# 4           University of Colorado Boulder      Public
# 9                          Yale University     Private
# 11    Central Connecticut State University      Public
# 12                        Barry University     Private
# ...                                    ...         ...
# 997                      Lander University      Public
# 998                  College of Charleston      Public
# 999        University of California-Irvine      Public
# 1000    University of California-San Diego      Public
# 1001             Fresno Pacific University     Private
#
#       10 Year Median Earnings  10 Year Mean Earnings  SAT Scores  ACT Scores
# 1                     74000.0                88800.0      1437.0        32.0
# 4                     50800.0                59700.0      1293.0        28.0
# 9                     83200.0               124400.0      1520.0        34.0
# 11                    47900.0                51600.0      1071.0        22.0
# 12                    45800.0                50900.0       970.0        19.0
# ...                       ...                    ...         ...         ...
# 997                   34200.0                38100.0      1022.0        20.0
# 998                   40700.0                48700.0      1176.0        25.0
# 999                   58400.0                65800.0      1291.0        29.0
# 1000                  59900.0                69600.0      1343.0        30.0
# 1001                  43900.0                45600.0      1050.0        20.0
#
# [695 rows x 6 columns]

# %%
# Get quartiles for ACT and SAT Scores
SAT_25th = np.percentile(df_clean["SAT Scores"], 25)
SAT_50th = np.percentile(df_clean["SAT Scores"], 50)
SAT_75th = np.percentile(df_clean["SAT Scores"], 75)
SAT_max = df_clean["SAT Scores"].max()

ACT_25th = np.percentile(df_clean["ACT Scores"], 25)
ACT_50th = np.percentile(df_clean["ACT Scores"], 50)
ACT_75th = np.percentile(df_clean["ACT Scores"], 75)
ACT_max = df_clean["ACT Scores"].max()

# %%
# Bin the SAT Scores
bins = [0, SAT_25th, SAT_50th, SAT_75th, SAT_max]
group_names = ["0 to " + str(SAT_25th), str(SAT_25th) + " to " + str(SAT_50th), str(SAT_50th) + " to " + str(SAT_75th), str(SAT_75th) + " to " + str(SAT_max)]

df_clean["SAT Bins"] = pd.cut(df["SAT Scores"], bins, labels = group_names)

# Bin the ACT Scores
bins = [0, ACT_25th, ACT_50th, ACT_75th, ACT_max]
group_names = ["0 to " + str(ACT_25th), str(ACT_25th) + " to " + str(ACT_50th), str(ACT_50th) + " to " + str(ACT_75th), str(ACT_75th) + " to " + str(ACT_max)]

df_clean["ACT Bins"] = pd.cut(df["ACT Scores"], bins, labels = group_names)
df_clean
# Out:
#                                School Name School Type  \
# 1        University of Southern California     Private
# 4           University of Colorado Boulder      Public
# 9                          Yale University     Private
# 11    Central Connecticut State University      Public
# 12                        Barry University     Private
# ...                                    ...         ...
# 997                      Lander University      Public
# 998                  College of Charleston      Public
# 999        University of California-Irvine      Public
# 1000    University of California-San Diego      Public
# 1001             Fresno Pacific University     Private
#
#       10 Year Median Earnings  10 Year Mean Earnings  SAT Scores  ACT Scores  \
# 1                     74000.0                88800.0      1437.0        32.0
# 4                     50800.0                59700.0      1293.0        28.0
# 9                     83200.0               124400.0      1520.0        34.0
# 11                    47900.0                51600.0      1071.0        22.0
# 12                    45800.0                50900.0       970.0        19.0
# ...                       ...                    ...         ...         ...
# 997                   34200.0                38100.0      1022.0        20.0
# 998                   40700.0                48700.0      1176.0        25.0
# 999                   58400.0                65800.0      1291.0        29.0
# 1000                  59900.0                69600.0      1343.0        30.0
# 1001                  43900.0                45600.0      1050.0        20.0
#
#               SAT Bins      ACT Bins
# 1     1229.5 to 1535.0  26.0 to 34.0
# 4     1229.5 to 1535.0  26.0 to 34.0
# 9     1229.5 to 1535.0  26.0 to 34.0
# 11         0 to 1081.5     0 to 22.0
# 12         0 to 1081.5     0 to 22.0
# ...                ...           ...
# 997        0 to 1081.5     0 to 22.0
# 998   1143.0 to 1229.5  24.0 to 26.0
# 999   1229.5 to 1535.0  26.0 to 34.0
# 1000  1229.5 to 1535.0  26.0 to 34.0
# 1001       0 to 1081.5     0 to 22.0
#
# [695 rows x 8 columns]

# %%
# Create a groupby with the bins
gb_ACT = df_clean.groupby(["ACT Bins"]).mean()
gb_ACT = gb_ACT.reset_index()
gb_ACT
# Out:
#        ACT Bins  10 Year Median Earnings  10 Year Mean Earnings   SAT Scores  \
# 0     0 to 22.0             39948.471616           44176.855895  1036.847162
# 1  22.0 to 24.0             44660.732984           49935.078534  1134.261780
# 2  24.0 to 26.0             48857.657658           55502.702703  1199.567568
# 3  26.0 to 34.0             60985.975610           72900.000000  1350.091463
#
#    ACT Scores
# 0   20.611354
# 1   23.497382
# 2   25.414414
# 3   29.652439

# %%
# Graph the data on bar charts
ypos = np.arange(len(gb_ACT["ACT Bins"]))

plt.xticks(ypos, gb_ACT["ACT Bins"])

plt.bar(ypos, gb_ACT["10 Year Mean Earnings"])
plt.title("ACT Scores Compared with Average Earnings")

plt.savefig("Graphs_and_Charts/ACT_Earnings.png")

plt.show()

# %%
# Create a scatterplot of ACT Scores vs Earnings
new_df.plot.scatter(x="ACT Scores",
                   y="10 Year Mean Earnings",
                   c="DarkBlue")

# Add regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(new_df["ACT Scores"],new_df["10 Year Mean Earnings"])
line = slope*new_df["ACT Scores"]+intercept
plt.plot(new_df["ACT Scores"], line, 'r', label='fitted line')
plt.title("Scatterplot of ACT Scores vs Earnings")

plt.savefig("Graphs_and_Charts/ACT_Earnings_Scatter.png", bbox_inches="tight")

plt.show()

# %%
# Create a groupby with the bins
gb_SAT = df_clean.groupby(["SAT Bins"]).mean()
gb_SAT = gb_SAT.reset_index()
gb_SAT
# Out:
#            SAT Bins  10 Year Median Earnings  10 Year Mean Earnings  \
# 0       0 to 1081.5             39824.712644           43844.827586
# 1  1081.5 to 1143.0             43144.252874           48254.597701
# 2  1143.0 to 1229.5             47320.231214           53179.768786
# 3  1229.5 to 1535.0             60231.609195           72098.275862
#
#     SAT Scores  ACT Scores
# 0  1015.505747   20.224138
# 1  1112.942529   22.827586
# 2  1180.601156   24.768786
# 3  1345.143678   29.402299

# %%
# Graph the data on bar charts
ypos = np.arange(len(gb_SAT["SAT Bins"]))

plt.xticks(ypos, gb_SAT["SAT Bins"], rotation = 30)

plt.bar(ypos, gb_SAT["10 Year Mean Earnings"])
plt.title("SAT Scores Compared with Average Earnings")

plt.savefig("Graphs_and_Charts/SAT_Earnings.png", bbox_inches = "tight")

plt.show()

# %%
# Create a scatterplot of SAT Scores vs Earnings
new_df.plot.scatter(x="SAT Scores",
                   y="10 Year Mean Earnings",
                   c="DarkBlue")

# Add regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(new_df["SAT Scores"],new_df["10 Year Mean Earnings"])
line = slope*new_df["SAT Scores"]+intercept
plt.plot(new_df["SAT Scores"], line, 'r', label='fitted line')
plt.title("Scatterplot of SAT Scores vs Earnings")

plt.savefig("Graphs_and_Charts/SAT_Earnings_Scatter.png", bbox_inches="tight")

plt.show()

# %%
# Run a T-test to compare Public and Private Schools
private = new_df[new_df["School Type"] == "Private"]
public = new_df[new_df["School Type"] == "Public"]

ttest_output = ttest_ind(private["10 Year Mean Earnings"], public["10 Year Mean Earnings"])
p_value = ttest_output[1]
p_value
# Out:
# 7.80366120920384e-27

# %%
# Create a Groupby for the School Type
gb_type = new_df.groupby(["School Type"]).mean()
gb_type = gb_type.reset_index()
gb_type
# Out:
#   School Type  10 Year Median Earnings  10 Year Mean Earnings   SAT Scores  \
# 0     Private             53154.861111           61680.208333  1220.666667
# 1      Public             43721.621622           49156.265356  1123.088452
#
#    ACT Scores
# 0   25.961806
# 1   23.132678

# %%
# Create a bar chart comparing school types
ypos = np.arange(len(gb_type["School Type"]))

plt.xticks(ypos, gb_type["School Type"])

plt.bar(ypos, gb_type["10 Year Mean Earnings"])
plt.title("School Type Compared with 10 Year Mean Earnings")

formatted_percent = ['%.2f' % elem for elem in gb_type["10 Year Mean Earnings"]]

for i, v in enumerate(formatted_percent):
    plt.text(ypos[i] - 0.1, 62000, str(v), color = "black")

plt.savefig("Graphs_and_Charts/School_Type_Comparison.png")

plt.show()
